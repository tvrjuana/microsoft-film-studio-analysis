# %%
import pandas as pd

df1 = pd.read_csv('data/tn.movie_budgets.csv', parse_dates=['release_date'])

# %%
#movie budgets
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 271.2+ KB

# %%
df1_clean = df1.copy()

# %%
df1_clean.drop(['id'], axis=1, inplace=True)

# %%
df1_clean['production_budget'] = df1_clean['production_budget'].str.replace(',', '').str.replace('$', '').astype(int)

df1_clean.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# 0          425000000   $760,507,625  $2,776,345,279
# 1          410600000   $241,063,875  $1,045,663,875
# 2          350000000    $42,762,350    $149,762,350
# 3          330600000   $459,005,868  $1,403,013,963
# 4          317000000   $620,181,382  $1,316,721,747

# %%
df1_clean['domestic_gross'] = df1_clean['domestic_gross'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
df1_clean['worldwide_gross'] = df1_clean['worldwide_gross'].str.replace(',', '').str.replace('$', '').astype(int)

df1_clean.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
df1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   datetime64[ns]
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   int64
#  3   domestic_gross     5782 non-null   int64
#  4   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 226.0+ KB

# %%
df2 = pd.read_csv('data/movie_profession.csv', index_col=0)
df2.head()
# Out:
#     movie_id primary_title              genres  averagerating  numvotes  \
# 0  tt0063540     Sunghursh  Action,Crime,Drama            7.0        77
# 1  tt0063540     Sunghursh  Action,Crime,Drama            7.0        77
# 2  tt0063540     Sunghursh  Action,Crime,Drama            7.0        77
# 3  tt0063540     Sunghursh  Action,Crime,Drama            7.0        77
# 4  tt0063540     Sunghursh  Action,Crime,Drama            7.0        77
#
#    category         primary_name
# 0     actor          Dilip Kumar
# 1   actress       Vyjayanthimala
# 2     actor         Balraj Sahni
# 3     actor        Sanjeev Kumar
# 4  director  Harnam Singh Rawail

# %%
df2_clean = df2.copy()

# %%
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406119 entries, 0 to 406118
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       406119 non-null  object
#  1   primary_title  406119 non-null  object
#  2   genres         402529 non-null  object
#  3   averagerating  406119 non-null  float64
#  4   numvotes       406119 non-null  int64
#  5   category       406119 non-null  object
#  6   primary_name   406119 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 24.8+ MB

# %%
df2_clean.isna().sum()
# Out:
# movie_id            0
# primary_title       0
# genres           3590
# averagerating       0
# numvotes            0
# category            0
# primary_name        0
# dtype: int64

# %%
df2_clean['genres'] = df2_clean['genres'].fillna('Unknown')

# %%
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406119 entries, 0 to 406118
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       406119 non-null  object
#  1   primary_title  406119 non-null  object
#  2   genres         406119 non-null  object
#  3   averagerating  406119 non-null  float64
#  4   numvotes       406119 non-null  int64
#  5   category       406119 non-null  object
#  6   primary_name   406119 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 24.8+ MB

# %%
df2_clean['genres'].unique()
# Out:
# array(['Action,Crime,Drama', 'Biography,Drama', 'Drama', 'Comedy,Drama',
#        'Comedy,Drama,Fantasy', 'Horror,Thriller',
#        'Adventure,Animation,Comedy', 'History', 'Documentary',
#        'Animation,Drama,History', 'Drama,Mystery',
#        'Action,Animation,Comedy', 'Crime,Drama', 'Unknown',
#        'Biography,Comedy,Drama', 'Action,Drama', 'Documentary,History',
#        'Sci-Fi', 'Comedy', 'Thriller', 'Adventure,Animation,Sci-Fi',
#        'Drama,Horror', 'Drama,Mystery,Thriller', 'Drama,Family',
#        'Adventure,Comedy,Romance', 'Adventure,Drama,Romance',
#        'Comedy,Crime,Drama', 'Biography', 'Horror',
#        'Adventure,Comedy,Drama', 'Drama,Sci-Fi,Thriller', 'Action',
#        'Comedy,Drama,Romance', 'Action,Adventure,Sci-Fi', 'Comedy,Family',
#        'Adventure', 'Drama,History,War', 'Action,Thriller',
#        'Comedy,Crime', 'Crime,Drama,Thriller', 'Action,Sci-Fi,Thriller',
#        'Fantasy', 'Drama,Mystery,Sci-Fi', 'Biography,Drama,History',
#        'Action,Comedy,Crime', 'Action,Adventure,Thriller',
#        'Horror,Mystery,Thriller', 'Action,Drama,Family',
#        'Comedy,Drama,Music', 'Drama,Fantasy,Horror',
#        'Drama,Romance,Sci-Fi', 'Drama,Thriller', 'Drama,Romance',
#        'Drama,Romance,War', 'Crime,Drama,Horror', 'Action,Comedy,Fantasy',
#        'Action,Adventure,Comedy', 'Action,Adventure,Animation',
#        'Action,Adventure,Fantasy', 'Comedy,Romance',
#        'Biography,Drama,Sport', 'Comedy,Drama,Sci-Fi',
#        'Adventure,Drama,Fantasy', 'Action,Crime,Thriller',
#        'Crime,Thriller', 'Adventure,Comedy,Western',
#        'Drama,Horror,Sci-Fi', 'Mystery,Thriller', 'Comedy,Horror',
#        'Musical', 'Adventure,Drama,Mystery', 'Drama,Fantasy',
#        'Fantasy,Horror,Thriller', 'Drama,Sport', 'Action,Adventure,Crime',
#        'Biography,Documentary,History', 'Drama,Music,Romance',
#        'Family,Sport', 'Adventure,Comedy', 'Action,Adventure,Drama',
#        'Adventure,Drama,History', 'Drama,History,Romance',
#        'Biography,Drama,Music', 'Adventure,Comedy,Family',
#        'Horror,Mystery,Romance', 'Action,Adventure,Horror',
#        'Animation,Family', 'Drama,Horror,Mystery',
#        'Drama,Fantasy,Romance', 'Biography,Documentary,Music',
#        'Animation,Family,Fantasy', 'Adventure,Comedy,Sci-Fi',
#        'Family,Fantasy', 'Horror,Mystery', 'Drama,Fantasy,Thriller',
#        'Documentary,Music', 'Comedy,Horror,Thriller',
#        'Action,Drama,Horror', 'Animation,Drama', 'Biography,Comedy,Crime',
#        'Drama,Mystery,War', 'Adventure,Comedy,Fantasy',
#        'Biography,Drama,Romance', 'Documentary,Drama',
#        'Biography,Crime,Drama', 'Action,Drama,Fantasy',
#        'Comedy,Family,Fantasy', 'Adventure,Animation,Family',
#        'Drama,Music', 'Adventure,Family,Fantasy', 'Drama,War',
#        'Adventure,Drama,Sci-Fi', 'Comedy,Music,Romance',
#        'Adventure,Family', 'Action,Horror,Thriller',
#        'Action,Biography,Crime', 'Crime,Drama,Romance',
#        'Animation,Comedy,Family', 'Comedy,Drama,War', 'Western',
#        'Comedy,Sci-Fi', 'Drama,Fantasy,Mystery', 'Adventure,Crime,Drama',
#        'Animation,Comedy,Crime', 'Sci-Fi,Thriller',
#        'Horror,Sci-Fi,Thriller', 'Action,Drama,Sport',
#        'Drama,Horror,Romance', 'Romance', 'Adventure,Horror,Thriller',
#        'Comedy,Crime,Mystery', 'Action,Animation,Drama', 'Mystery',
#        'Action,Crime,Horror', 'Adventure,Drama,Thriller',
#        'Comedy,Musical,Romance', 'Action,Drama,Thriller',
#        'Animation,Comedy,Fantasy', 'Horror,Mystery,Sci-Fi',
#        'Adventure,Drama,Horror', 'Animation,Comedy,Sci-Fi',
#        'Action,Horror,Sci-Fi', 'Adventure,Fantasy,Mystery',
#        'Drama,Sci-Fi', 'Mystery,Romance', 'Action,Adventure,Family',
#        'Comedy,Crime,Thriller', 'Action,Mystery,Thriller',
#        'Action,Drama,Sci-Fi', 'Crime,Documentary', 'Crime,Drama,History',
#        'Animation,Crime,Music', 'Action,Mystery,Sci-Fi',
#        'Adventure,Drama,Family', 'Drama,Fantasy,History',
#        'Drama,Musical,Romance', 'Biography,Drama,Thriller', 'Crime',
#        'Animation', 'Comedy,Horror,Sci-Fi', 'Action,Biography,Drama',
#        'Action,Comedy,Horror', 'Comedy,Fantasy', 'Action,Crime', 'Family',
#        'Adventure,Fantasy', 'Biography,Drama,Family',
#        'Adventure,Animation,Fantasy', 'Action,Adventure,History',
#        'Comedy,Drama,Family', 'Comedy,Documentary,Sport',
#        'Biography,Documentary', 'Documentary,History,War',
#        'Horror,Romance,Thriller', 'Crime,Documentary,Drama',
#        'Adventure,Drama', 'Documentary,Sport', 'Crime,Mystery,Thriller',
#        'Action,Fantasy,History', 'Sport', 'Comedy,Drama,Sport',
#        'Action,Comedy', 'Action,Fantasy,Western', 'Action,Comedy,Sci-Fi',
#        'Adventure,Horror,Sci-Fi', 'Fantasy,Horror,Mystery', 'Music',
#        'Comedy,Family,Thriller', 'Comedy,Thriller',
#        'Action,Fantasy,Horror', 'Action,Comedy,Romance',
#        'Action,Drama,Romance', 'Comedy,Drama,Mystery',
#        'Action,Family,Fantasy', 'Action,History', 'Biography,Drama,War',
#        'Documentary,War', 'Animation,Biography',
#        'Documentary,Drama,Sci-Fi', 'Action,Crime,Sci-Fi',
#        'Fantasy,Horror', 'Drama,History', 'Comedy,Horror,Musical',
#        'Action,Animation,Fantasy', 'Action,Fantasy,Thriller',
#        'Biography,Drama,Fantasy', 'Comedy,Fantasy,Horror',
#        'Action,Crime,Mystery', 'Drama,Horror,Thriller',
#        'Crime,Drama,Mystery', 'Crime,Horror,Thriller',
#        'Drama,Romance,Thriller', 'Action,Comedy,Documentary',
#        'Comedy,Documentary', 'Crime,Drama,Music', 'Biography,History',
#        'Drama,Music,Musical', 'Action,Sci-Fi', 'Action,Adventure',
#        'Action,Horror,Mystery', 'Documentary,Drama,History',
#        'Drama,Musical', 'Adventure,Comedy,Crime', 'Action,Drama,Western',
#        'Comedy,Musical', 'Crime,Sport,Thriller', 'Animation,Comedy,Drama',
#        'Adventure,Biography,Comedy', 'Adventure,Animation,Drama',
#        'Adventure,Animation', 'Family,Fantasy,Horror',
#        'Crime,Drama,Fantasy', 'Adventure,Biography',
#        'Action,Adventure,Western', 'Adventure,Biography,Drama',
#        'Animation,Comedy,Romance', 'Mystery,Sci-Fi,Thriller',
#        'Comedy,Drama,Horror', 'Documentary,Family,News',
#        'Comedy,Family,Romance', 'Adventure,Documentary',
#        'Adventure,Comedy,Music', 'Crime,Drama,War', 'Comedy,Western',
#        'Drama,Musical,War', 'Comedy,Drama,Musical',
#        'Animation,Crime,Drama', 'Drama,Mystery,Romance',
#        'Action,Romance,Sci-Fi', 'Crime,Documentary,History',
#        'Action,Drama,History', 'Horror,Sci-Fi',
#        'Documentary,History,Sport', 'Action,Comedy,Drama',
#        'Action,Fantasy,War', 'Comedy,Drama,History',
#        'Action,Drama,Mystery', 'Comedy,Sport', 'Comedy,Mystery',
#        'Drama,Thriller,Western', 'Action,Drama,War',
#        'Adventure,Comedy,Horror', 'Action,Comedy,Family',
#        'Comedy,Crime,Music', 'Comedy,Crime,Romance',
#        'Adventure,Drama,Sport', 'Comedy,Fantasy,Romance',
#        'Drama,Fantasy,Sci-Fi', 'Drama,Family,Fantasy', 'Sci-Fi,Western',
#        'Comedy,Music', 'Adventure,Biography,Documentary',
#        'Crime,Documentary,Music', 'Crime,Horror,Mystery',
#        'Adventure,Romance', 'Horror,Sport,Thriller',
#        'Comedy,Crime,History', 'Action,Adventure,Romance',
#        'Biography,Documentary,Sport', 'Horror,Music,Sci-Fi',
#        'Action,Drama,Music', 'Action,Adventure,Mystery',
#        'Comedy,History,War', 'Action,Fantasy,Sci-Fi',
#        'Adventure,Horror,Mystery', 'Animation,Horror',
#        'Adventure,Mystery,Romance', 'Romance,Thriller',
#        'Documentary,Family', 'Biography,Documentary,Drama',
#        'Animation,Comedy', 'Adventure,Sci-Fi', 'Comedy,Drama,Western',
#        'Comedy,Documentary,History', 'Action,Comedy,Thriller',
#        'Drama,Fantasy,Music', 'Action,Thriller,War', 'Drama,Thriller,War',
#        'Action,War', 'Biography,Comedy,History', 'Comedy,Family,Musical',
#        'Drama,Romance,Sport', 'Adventure,Mystery', 'Drama,Western',
#        'Animation,Sci-Fi', 'Romance,Sci-Fi,Thriller',
#        'Action,Adventure,Biography', 'Comedy,Family,Sport',
#        'Biography,Documentary,Fantasy', 'Comedy,Romance,Sci-Fi',
#        'Adventure,Fantasy,Horror', 'Adventure,Drama,Western',
#        'Comedy,Drama,Thriller', 'Comedy,Romance,Sport', 'History,Music',
#        'Documentary,Drama,Sport', 'Documentary,Drama,Music',
#        'Biography,Documentary,Romance', 'Documentary,History,Music',
#        'Adventure,Crime,Thriller', 'Drama,Family,Sport',
#        'Drama,Family,Music', 'Documentary,News', 'Action,Horror',
#        'Horror,Romance', 'Documentary,Drama,News',
#        'Action,History,Thriller', 'Adventure,History',
#        'Adventure,Mystery,Sci-Fi', 'Biography,Comedy,Documentary',
#        'Drama,History,Thriller', 'Documentary,Drama,Family',
#        'Family,Fantasy,Romance', 'Comedy,Documentary,Music',
#        'Comedy,Fantasy,Music', 'Comedy,Family,Sci-Fi',
#        'Adventure,Documentary,News', 'Crime,Mystery,Sci-Fi',
#        'Comedy,Crime,Family', 'Family,Musical', 'Biography,Drama,Musical',
#        'Music,Romance', 'Fantasy,Mystery,Romance',
#        'Adventure,Crime,Documentary', 'Documentary,Family,Music',
#        'Animation,Documentary,News', 'Adventure,Documentary,Family',
#        'Biography,Documentary,Family', 'Adventure,Documentary,Music',
#        'Mystery,Thriller,Western', 'Comedy,Crime,Horror',
#        'Action,Animation,Horror', 'War', 'Adventure,Documentary,History',
#        'Animation,Biography,Comedy', 'Adventure,Horror',
#        'Adventure,Documentary,Drama', 'Comedy,Documentary,Drama',
#        'Animation,Documentary,Music', 'Documentary,History,News',
#        'Comedy,Sci-Fi,Thriller', 'Fantasy,Sci-Fi',
#        'Action,Biography,Comedy', 'Action,Adventure,Documentary',
#        'Comedy,Mystery,Romance', 'Biography,Comedy', 'Action,Animation',
#        'Thriller,Western', 'Adventure,Documentary,Sport',
#        'Documentary,Western', 'Action,Comedy,Western',
#        'Drama,Fantasy,Musical', 'Action,Biography,Documentary',
#        'Documentary,Horror', 'Drama,Family,Sci-Fi', 'Drama,Music,Sci-Fi',
#        'Documentary,History,Sci-Fi', 'Documentary,Thriller',
#        'Documentary,Romance', 'Comedy,Horror,Romance',
#        'Adventure,Drama,Music', 'Animation,Comedy,Mystery',
#        'Fantasy,Horror,Musical', 'Action,Sci-Fi,Western',
#        'Documentary,Drama,Reality-TV', 'Action,Documentary,Sport',
#        'Action,Fantasy', 'Fantasy,Thriller', 'Animation,Drama,Mystery',
#        'Documentary,Music,Musical', 'Thriller,War', 'Documentary,Mystery',
#        'Documentary,Reality-TV', 'Action,Documentary,History',
#        'Animation,Biography,Documentary', 'Biography,Documentary,Mystery',
#        'Crime,Drama,Sport', 'Drama,Music,Thriller',
#        'Action,Documentary,Family', 'Action,Documentary,War',
#        'Animation,Drama,Family', 'Documentary,Family,History',
#        'Action,Crime,Fantasy', 'Horror,Musical', 'Action,Documentary',
#        'Action,Crime,Romance', 'Documentary,Drama,Mystery',
#        'Adventure,Horror,Western', 'Biography,Crime,Documentary',
#        'Comedy,Crime,Documentary', 'Musical,Romance',
#        'Animation,Documentary,Family', 'Crime,Documentary,Mystery',
#        'Comedy,Documentary,News', 'Drama,Family,Horror',
#        'Comedy,Romance,Thriller', 'Comedy,Horror,Mystery',
#        'Fantasy,Sci-Fi,Thriller', 'Adventure,Horror,Romance',
#        'Adventure,Comedy,Thriller', 'Documentary,Drama,War',
#        'Biography,Romance,War', 'Adventure,Comedy,Mystery',
#        'Comedy,Family,Music', 'Drama,Family,Thriller',
#        'Drama,Family,History', 'Action,Documentary,Drama',
#        'Fantasy,Horror,Sci-Fi', 'Fantasy,Romance', 'Drama,News,War',
#        'Crime,Documentary,News', 'Biography,Documentary,News',
#        'Animation,Biography,Drama', 'Biography,Documentary,War',
#        'Fantasy,Music', 'Action,Family,Sci-Fi', 'Drama,Family,Romance',
#        'Animation,Drama,Romance', 'Fantasy,History,Romance',
#        'Comedy,Mystery,Thriller', 'Action,Animation,Sci-Fi',
#        'Family,Mystery', 'Action,Comedy,Sport', 'Action,Mystery',
#        'Action,Animation,Crime', 'Crime,Drama,Family',
#        'Documentary,Musical', 'Mystery,Romance,Thriller',
#        'Animation,Comedy,Musical', 'Animation,Drama,Fantasy',
#        'Animation,Music', 'Biography,Fantasy,Horror',
#        'Adventure,Comedy,Documentary', 'Fantasy,Romance,Sci-Fi',
#        'Adventure,Crime,Family', 'Animation,Documentary',
#        'Drama,Horror,Music', 'Adventure,Family,Mystery', 'Comedy,History',
#        'Action,Romance,Thriller', 'Family,Romance',
#        'Adventure,Animation,Biography', 'Action,Fantasy,Mystery',
#        'Fantasy,Mystery,Thriller', 'Comedy,Crime,Sport',
#        'Action,Animation,Family', 'Animation,Musical', 'Action,Family',
#        'Animation,Fantasy,Horror', 'Documentary,Sci-Fi',
#        'Drama,Family,Musical', 'Adventure,Documentary,Mystery',
#        'Animation,Family,Musical', 'Biography,Drama,Horror',
#        'Drama,History,Musical', 'Drama,Music,War',
#        'Animation,Mystery,Sci-Fi', 'Fantasy,Romance,Thriller',
#        'Biography,Thriller', 'Crime,Mystery', 'Animation,Romance,Sci-Fi',
#        'Animation,Documentary,Drama', 'Documentary,Drama,Romance',
#        'Documentary,Music,Romance', 'Biography,Comedy,Music',
#        'Adventure,Animation,Documentary', 'Action,History,Horror',
#        'Documentary,Family,Sport', 'Animation,History,Musical',
#        'Comedy,Documentary,War', 'Adventure,Biography,History',
#        'Adventure,Fantasy,Sci-Fi', 'Action,Sport',
#        'Animation,Horror,Sci-Fi', 'Drama,Musical,Sci-Fi',
#        'Documentary,Family,Romance', 'Drama,Family,War',
#        'History,Horror,Thriller', 'Comedy,Music,Sci-Fi',
#        'Biography,Comedy,Family', 'Documentary,Family,Fantasy',
#        'Drama,Romance,Western', 'Animation,Horror,Thriller',
#        'Adventure,Fantasy,Musical', 'Comedy,Musical,War',
#        'Animation,Thriller', 'Crime,Romance,Thriller', 'Action,Western',
#        'Action,Thriller,Western', 'Comedy,Fantasy,Musical',
#        'Comedy,Fantasy,Sci-Fi', 'Drama,Fantasy,Western',
#        'Adventure,Mystery,Thriller', 'Documentary,Drama,Musical',
#        'Adventure,Comedy,History', 'Documentary,News,War',
#        'Documentary,Fantasy,Horror', 'Action,Comedy,Mystery',
#        'Drama,Family,Mystery', 'Drama,History,Sport',
#        'Animation,Crime,Documentary', 'Action,Romance',
#        'Comedy,Thriller,Western', 'Biography,Documentary,Musical',
#        'Action,Crime,Music', 'Fantasy,Mystery,Sci-Fi', 'Animation,Sport',
#        'Biography,Comedy,Romance', 'Documentary,History,Mystery',
#        'Action,Comedy,Musical', 'Animation,Drama,Thriller',
#        'Family,Fantasy,Sci-Fi', 'Action,Adventure,War', 'Comedy,War',
#        'Action,Musical', 'Adventure,Documentary,Western',
#        'Crime,Drama,Western', 'Drama,Musical,Thriller',
#        'Animation,Drama,Sci-Fi', 'Mystery,Sci-Fi', 'Animation,Fantasy',
#        'Comedy,Mystery,Sci-Fi', 'Action,Drama,News',
#        'Comedy,Documentary,Romance', 'Crime,Drama,Musical',
#        'Fantasy,Mystery', 'Crime,History,Thriller',
#        'Crime,Sci-Fi,Thriller', 'Comedy,Family,Western',
#        'Crime,Horror,Musical', 'Documentary,Drama,Horror',
#        'Action,Fantasy,Romance', 'Drama,History,Mystery',
#        'Fantasy,Music,Romance', 'Comedy,Documentary,Family',
#        'Animation,Comedy,Documentary', 'Action,Biography,History',
#        'Crime,Horror', 'Animation,Music,Romance',
#        'Animation,Documentary,War', 'Animation,Drama,War',
#        'Biography,History,Thriller', 'Action,Horror,Western',
#        'Action,Comedy,Music', 'Action,Family,Mystery',
#        'Adventure,Family,Western', 'History,Thriller,War',
#        'Documentary,History,Western', 'Adventure,History,Mystery',
#        'Adventure,Animation,History', 'Comedy,Fantasy,Thriller',
#        'Drama,Sport,Thriller', 'Action,Comedy,History',
#        'Action,Romance,Sport', 'Adventure,Drama,War',
#        'Documentary,Fantasy', 'Comedy,Horror,Sport',
#        'Family,Musical,Sport', 'Music,Mystery', 'Crime,Drama,Sci-Fi',
#        'Animation,History', 'Biography,Documentary,Sci-Fi',
#        'Action,Musical,Romance', 'Drama,History,Sci-Fi',
#        'Action,Romance,War', 'Animation,Family,Music',
#        'Horror,Music,Mystery', 'Adventure,Thriller',
#        'Adventure,Family,Musical', 'Romance,Sport',
#        'Action,Crime,Musical', 'Documentary,Music,Sport',
#        'Adventure,Sport', 'Action,Crime,Documentary', 'Musical,Sci-Fi',
#        'Comedy,History,Mystery', 'Documentary,History,Horror',
#        'Documentary,Music,Mystery', 'Music,Mystery,Thriller',
#        'Fantasy,Musical,Sci-Fi', 'Animation,Sci-Fi,Thriller',
#        'Fantasy,Musical', 'Action,Crime,Sport', 'Crime,Mystery,Romance',
#        'Documentary,Fantasy,History', 'Crime,Fantasy,Mystery',
#        'Adventure,Documentary,Reality-TV', 'Adventure,Romance,Sport',
#        'Horror,Music,Thriller', 'Adventure,Family,Horror',
#        'Comedy,Musical,Sci-Fi', 'Adventure,Biography,Crime',
#        'Comedy,Music,Musical', 'Comedy,Horror,Music',
#        'Animation,Biography,History', 'Family,Mystery,Thriller',
#        'Drama,Game-Show,Thriller', 'Horror,War',
#        'Adventure,Comedy,Musical', 'Documentary,Drama,Western', 'News',
#        'Action,Music', 'Adventure,Family,Romance',
#        'Animation,Fantasy,Mystery', 'Documentary,Music,War',
#        'Fantasy,Horror,Music', 'Adventure,Sci-Fi,Thriller',
#        'Adventure,Documentary,Romance', 'Animation,War',
#        'Drama,History,Horror', 'Drama,Sci-Fi,Western',
#        'Biography,Crime,History', 'Animation,Horror,Music',
#        'Family,Thriller', 'Comedy,Documentary,Thriller', 'History,Horror',
#        'Crime,Documentary,Thriller', 'Adventure,Animation,Musical',
#        'Music,Musical', 'Adventure,Drama,Musical',
#        'Adventure,Family,Sci-Fi', 'Biography,Drama,News',
#        'Action,Adventure,Music', 'Documentary,History,Romance',
#        'Action,Crime,History', 'Family,Horror,Thriller',
#        'Documentary,Fantasy,Sci-Fi', 'Romance,War', 'Crime,Sci-Fi',
#        'Comedy,Family,Horror', 'Action,Sci-Fi,War',
#        'Documentary,Music,News', 'Action,Family,Romance',
#        'Biography,Documentary,Western', 'Animation,Drama,Horror',
#        'Horror,Romance,Sci-Fi', 'Family,Sci-Fi,Thriller',
#        'Action,History,Romance', 'Romance,Sci-Fi',
#        'Animation,Drama,Musical', 'Crime,Romance',
#        'Comedy,Documentary,Horror', 'Animation,Comedy,Music',
#        'Family,Fantasy,Western', 'Animation,History,Horror',
#        'Action,Horror,Sport', 'Musical,Romance,Thriller',
#        'Documentary,Mystery,News', 'Horror,Thriller,War',
#        'Crime,Music,Mystery', 'Drama,Horror,Western',
#        'Drama,Mystery,Western', 'Drama,Music,Mystery',
#        'Music,Musical,Romance', 'Crime,Family,Thriller', 'History,Sci-Fi',
#        'Mystery,Romance,Sci-Fi', 'Biography,History,Romance',
#        'Drama,History,News', 'Action,Sport,Thriller',
#        'Adventure,Crime,Western', 'Action,Animation,History',
#        'Documentary,News,Thriller', 'Drama,Sci-Fi,War',
#        'Drama,Horror,Musical', 'Documentary,History,Thriller',
#        'Documentary,Drama,Thriller', 'Family,Music,Romance',
#        'Animation,Family,History', 'Crime,Western',
#        'Comedy,Documentary,Mystery', 'Biography,Music', 'Horror,Music',
#        'Adventure,Fantasy,Thriller', 'Crime,Fantasy,Horror',
#        'Family,Musical,Romance', 'Comedy,Documentary,Western',
#        'Mystery,News,Thriller', 'Comedy,Drama,News',
#        'Drama,History,Music', 'Comedy,Family,Mystery', 'Crime,Musical',
#        'Action,Horror,Romance', 'Comedy,News',
#        'Biography,History,Mystery', 'Documentary,Family,Western',
#        'Animation,Family,Sport', 'Action,Musical,Thriller',
#        'Biography,Drama,Mystery', 'Animation,Biography,Family',
#        'Biography,Comedy,Fantasy', 'Action,Family,Western',
#        'Horror,Thriller,Western', 'Biography,Family,Fantasy',
#        'Adventure,Music', 'Drama,News', 'Animation,Biography,Crime',
#        'Family,Fantasy,Musical', 'Documentary,Musical,Mystery',
#        'Adventure,Documentary,Fantasy', 'Drama,News,Thriller',
#        'Adventure,History,Romance', 'Comedy,Fantasy,Mystery',
#        'Musical,Thriller', 'Comedy,Documentary,Musical',
#        'Documentary,News,Romance', 'Crime,Fantasy,Thriller',
#        'Animation,Fantasy,Music', 'Documentary,Drama,Fantasy',
#        'Game-Show', 'Adventure,Fantasy,History',
#        'Biography,History,Music', 'Drama,War,Western',
#        'Biography,Crime,Thriller', 'Crime,Family',
#        'Adventure,Music,Sci-Fi', 'Crime,Music,Thriller',
#        'Biography,Family,Sport', 'Family,History,War',
#        'Action,Animation,Documentary', 'Documentary,History,Musical',
#        'Animation,Comedy,History', 'Crime,Family,Horror',
#        'Adventure,Fantasy,Romance', 'Comedy,Family,History',
#        'Biography,Horror', 'Action,History,War',
#        'Animation,Documentary,History', 'Documentary,Mystery,Thriller',
#        'Family,Sci-Fi', 'History,Romance', 'Adventure,Romance,Sci-Fi',
#        'Crime,Horror,Sci-Fi', 'Action,Drama,Musical',
#        'Action,Musical,Sci-Fi', 'Action,Romance,Western',
#        'Family,Horror,Romance', 'Fantasy,History,Mystery',
#        'Drama,History,Western', 'Biography,Documentary,Horror',
#        'Adventure,Crime,Romance', 'Comedy,Music,War',
#        'Crime,Musical,Thriller', 'Comedy,Crime,Fantasy',
#        'Documentary,Horror,News', 'Action,Biography',
#        'Crime,Documentary,Family', 'Biography,Family,History',
#        'Documentary,News,Reality-TV', 'Adventure,Western',
#        'Horror,Western', 'Crime,Horror,Romance',
#        'Action,Documentary,News', 'Documentary,Horror,Romance',
#        'Sport,Thriller', 'Comedy,Sport,Western', 'Comedy,Crime,Musical',
#        'Comedy,Sci-Fi,Western', 'Action,Biography,Thriller',
#        'Action,Documentary,Thriller', 'Crime,Drama,News',
#        'Animation,Fantasy,Sci-Fi', 'Crime,Documentary,War', 'Reality-TV',
#        'Action,Comedy,War', 'Comedy,Sci-Fi,Sport',
#        'Documentary,Family,War', 'Comedy,History,Horror',
#        'History,Western', 'Animation,Horror,Mystery',
#        'Adventure,Family,Sport', 'Biography,War',
#        'History,Romance,Western', 'Biography,Family',
#        'Musical,Mystery,Thriller', 'Animation,History,Music',
#        'Biography,Documentary,Thriller', 'Adventure,Biography,Family',
#        'Animation,Horror,Romance', 'History,Thriller',
#        'Action,Animation,Music', 'Animation,Comedy,Horror',
#        'Crime,Thriller,Western', 'Biography,Comedy,Horror',
#        'Adult,Horror', 'Drama,Sci-Fi,Sport', 'Documentary,Family,Mystery',
#        'Comedy,History,Music', 'Action,Mystery,Western',
#        'Family,Fantasy,Music', 'Documentary,Family,Musical',
#        'Animation,Romance', 'Drama,Mystery,News',
#        'Action,Animation,Sport', 'Adventure,Romance,Thriller',
#        'Drama,Family,Western', 'Adventure,Comedy,War',
#        'Action,Animation,Biography', 'Comedy,Horror,War',
#        'Animation,Mystery,Thriller', 'History,War', 'Drama,Music,News',
#        'Comedy,Documentary,Fantasy', 'Animation,Drama,Music',
#        'Horror,Musical,Romance', 'Family,Music',
#        'Documentary,Horror,Mystery', 'Drama,Family,News',
#        'Fantasy,Horror,Western', 'Adventure,Documentary,Sci-Fi',
#        'Fantasy,History,Music', 'Comedy,Documentary,Sci-Fi',
#        'Animation,Biography,Fantasy', 'Comedy,Romance,Western',
#        'Comedy,Horror,Western', 'History,Musical,Romance',
#        'Fantasy,Horror,Romance', 'Comedy,Musical,Western',
#        'Documentary,News,Sport', 'Adventure,News',
#        'Crime,Documentary,Romance', 'History,Horror,Mystery',
#        'Action,Documentary,Horror', 'History,Sci-Fi,Thriller',
#        'Adventure,Documentary,Musical', 'Comedy,Reality-TV',
#        'Family,Fantasy,Mystery', 'Documentary,History,Reality-TV',
#        'Animation,Drama,Sport', 'Biography,Drama,Western',
#        'Animation,Western', 'Adventure,Music,Romance',
#        'Adventure,Family,Music', 'Family,Mystery,Sport',
#        'Documentary,Sport,War', 'Animation,Fantasy,History',
#        'Comedy,Musical,Sport', 'Crime,Documentary,Fantasy',
#        'Action,Crime,Western', 'Adventure,Animation,Horror',
#        'Comedy,History,News', 'Comedy,Drama,Reality-TV', 'Family,Western',
#        'Documentary,Mystery,Sci-Fi', 'Animation,Crime,Thriller',
#        'Animation,Family,Sci-Fi', 'Biography,Thriller,Western',
#        'Drama,Musical,Western', 'Crime,History',
#        'Animation,Crime,Mystery', 'History,Romance,War',
#        'Action,Mystery,Romance', 'Adventure,Documentary,Horror',
#        'Drama,Fantasy,War', 'History,Sport', 'Biography,Sport',
#        'Horror,Sci-Fi,War', 'Comedy,History,Romance', 'Biography,Crime',
#        'Animation,Sci-Fi,War', 'Animation,Documentary,Mystery',
#        'Biography,Fantasy', 'Comedy,Crime,Sci-Fi',
#        'Action,Adventure,Sport', 'Biography,Musical', 'Romance,Western',
#        'Documentary,Horror,Thriller', 'Documentary,Sport,Thriller',
#        'History,Musical', 'Adventure,Crime', 'Comedy,History,Musical',
#        'Documentary,Music,Reality-TV', 'Crime,Documentary,Sport',
#        'Adventure,Crime,Horror', 'Biography,Romance',
#        'Action,Family,Thriller', 'Comedy,Sport,Thriller',
#        'Action,Adult,Comedy', 'Adventure,Fantasy,War',
#        'Biography,Documentary,Reality-TV', 'Animation,Family,Mystery',
#        'Biography,History,War', 'Animation,Fantasy,Romance',
#        'Comedy,History,Sport', 'Biography,Music,Romance',
#        'Comedy,Fantasy,Sport', 'Adventure,Musical',
#        'Romance,Thriller,War', 'Sci-Fi,War', 'Action,Adventure,Musical',
#        'Crime,Mystery,Western', 'Family,War', 'Adventure,Animation,Crime',
#        'History,Mystery,Thriller', 'Musical,Mystery,Sci-Fi',
#        'Crime,Music', 'Adventure,History,Sci-Fi',
#        'Musical,Romance,Western', 'Comedy,Music,Thriller', 'Drama,Short',
#        'Documentary,Family,Sci-Fi'], dtype=object)

# %%
df2_clean['genres'].value_counts().head(15)
# Out:
# Drama                   74101
# Comedy                  35998
# Documentary             26504
# Horror                  17423
# Comedy,Drama            17216
# Thriller                 9931
# Drama,Romance            9777
# Comedy,Romance           8168
# Comedy,Drama,Romance     7921
# Horror,Thriller          6464
# Drama,Thriller           6420
# Action                   6231
# Romance                  4464
# Comedy,Horror            3743
# Action,Crime,Drama       3680
# Name: genres, dtype: int64

# %%
df2_clean.rename({'primary_title':'movie', 'primary_name': 'name'}, axis=1, inplace=True)

# %%
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406119 entries, 0 to 406118
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       406119 non-null  object
#  1   movie          406119 non-null  object
#  2   genres         406119 non-null  object
#  3   averagerating  406119 non-null  float64
#  4   numvotes       406119 non-null  int64
#  5   category       406119 non-null  object
#  6   name           406119 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 24.8+ MB

# %%
df3 = pd.read_csv('data/bom.movie_gross.csv')

# %%
df3.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df3.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
df3_clean = df3.copy()

# %%
df3_clean = df3_clean.drop(['domestic_gross'], axis = 1)

# %%
df3_clean = df3_clean.drop(['foreign_gross'], axis = 1)

# %%
df3_clean = df3_clean.drop(['year'], axis = 1)

# %%
df3_clean.head()
# Out:
#                                          title studio
# 0                                  Toy Story 3     BV
# 1                   Alice in Wonderland (2010)     BV
# 2  Harry Potter and the Deathly Hallows Part 1     WB
# 3                                    Inception     WB
# 4                          Shrek Forever After   P/DW

# %%
df3_clean.dropna(subset=['studio'], inplace=True)

# %%
df3_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   3382 non-null   object
#  1   studio  3382 non-null   object
# dtypes: object(2)
# memory usage: 79.3+ KB

# %%
df3_clean.rename({'title':'movie'}, axis=1, inplace=True)

# %%
df3_clean.head()
# Out:
#                                          movie studio
# 0                                  Toy Story 3     BV
# 1                   Alice in Wonderland (2010)     BV
# 2  Harry Potter and the Deathly Hallows Part 1     WB
# 3                                    Inception     WB
# 4                          Shrek Forever After   P/DW

# %%
movie_revenue = df1_clean.merge(df3_clean)

# %%
movie_revenue.head()
# Out:
#   release_date                                        movie  \
# 0   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1   2015-05-01                      Avengers: Age of Ultron
# 2   2018-04-27                       Avengers: Infinity War
# 3   2017-11-17                               Justice League
# 4   2015-11-06                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross studio
# 0          410600000       241063875       1045663875     BV
# 1          330600000       459005868       1403013963     BV
# 2          300000000       678815482       2048134200     BV
# 3          300000000       229024295        655945209     WB
# 4          300000000       200074175        879620923   Sony

# %%
movie_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1246 entries, 0 to 1245
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       1246 non-null   datetime64[ns]
#  1   movie              1246 non-null   object
#  2   production_budget  1246 non-null   int64
#  3   domestic_gross     1246 non-null   int64
#  4   worldwide_gross    1246 non-null   int64
#  5   studio             1246 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 68.1+ KB

# %%
master_movie = movie_revenue.merge(df2_clean)

# %%
master_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9645 entries, 0 to 9644
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       9645 non-null   datetime64[ns]
#  1   movie              9645 non-null   object
#  2   production_budget  9645 non-null   int64
#  3   domestic_gross     9645 non-null   int64
#  4   worldwide_gross    9645 non-null   int64
#  5   studio             9645 non-null   object
#  6   movie_id           9645 non-null   object
#  7   genres             9645 non-null   object
#  8   averagerating      9645 non-null   float64
#  9   numvotes           9645 non-null   int64
#  10  category           9645 non-null   object
#  11  name               9645 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 979.6+ KB

# %%
master_movie.head(30)
# Out:
#    release_date                                        movie  \
# 0    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 4    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 5    2015-05-01                      Avengers: Age of Ultron
# 6    2015-05-01                      Avengers: Age of Ultron
# 7    2015-05-01                      Avengers: Age of Ultron
# 8    2015-05-01                      Avengers: Age of Ultron
# 9    2015-05-01                      Avengers: Age of Ultron
# 10   2015-05-01                      Avengers: Age of Ultron
# 11   2018-04-27                       Avengers: Infinity War
# 12   2018-04-27                       Avengers: Infinity War
# 13   2018-04-27                       Avengers: Infinity War
# 14   2018-04-27                       Avengers: Infinity War
# 15   2018-04-27                       Avengers: Infinity War
# 16   2018-04-27                       Avengers: Infinity War
# 17   2017-11-17                               Justice League
# 18   2017-11-17                               Justice League
# 19   2017-11-17                               Justice League
# 20   2017-11-17                               Justice League
# 21   2017-11-17                               Justice League
# 22   2015-11-06                                      Spectre
# 23   2015-11-06                                      Spectre
# 24   2015-11-06                                      Spectre
# 25   2015-11-06                                      Spectre
# 26   2015-11-06                                      Spectre
# 27   2012-07-20                        The Dark Knight Rises
# 28   2012-07-20                        The Dark Knight Rises
# 29   2012-07-20                        The Dark Knight Rises
#
#     production_budget  domestic_gross  worldwide_gross studio   movie_id  \
# 0           410600000       241063875       1045663875     BV  tt1298650
# 1           410600000       241063875       1045663875     BV  tt1298650
# 2           410600000       241063875       1045663875     BV  tt1298650
# 3           410600000       241063875       1045663875     BV  tt1298650
# 4           410600000       241063875       1045663875     BV  tt1298650
# 5           330600000       459005868       1403013963     BV  tt2395427
# 6           330600000       459005868       1403013963     BV  tt2395427
# 7           330600000       459005868       1403013963     BV  tt2395427
# 8           330600000       459005868       1403013963     BV  tt2395427
# 9           330600000       459005868       1403013963     BV  tt2395427
# 10          330600000       459005868       1403013963     BV  tt2395427
# 11          300000000       678815482       2048134200     BV  tt4154756
# 12          300000000       678815482       2048134200     BV  tt4154756
# 13          300000000       678815482       2048134200     BV  tt4154756
# 14          300000000       678815482       2048134200     BV  tt4154756
# 15          300000000       678815482       2048134200     BV  tt4154756
# 16          300000000       678815482       2048134200     BV  tt4154756
# 17          300000000       229024295        655945209     WB  tt0974015
# 18          300000000       229024295        655945209     WB  tt0974015
# 19          300000000       229024295        655945209     WB  tt0974015
# 20          300000000       229024295        655945209     WB  tt0974015
# 21          300000000       229024295        655945209     WB  tt0974015
# 22          300000000       200074175        879620923   Sony  tt2379713
# 23          300000000       200074175        879620923   Sony  tt2379713
# 24          300000000       200074175        879620923   Sony  tt2379713
# 25          300000000       200074175        879620923   Sony  tt2379713
# 26          300000000       200074175        879620923   Sony  tt2379713
# 27          275000000       448139099       1084439099     WB  tt1345836
# 28          275000000       448139099       1084439099     WB  tt1345836
# 29          275000000       448139099       1084439099     WB  tt1345836
#
#                        genres  averagerating  numvotes  category  \
# 0    Action,Adventure,Fantasy            6.6    447624     actor
# 1    Action,Adventure,Fantasy            6.6    447624   actress
# 2    Action,Adventure,Fantasy            6.6    447624     actor
# 3    Action,Adventure,Fantasy            6.6    447624     actor
# 4    Action,Adventure,Fantasy            6.6    447624  director
# 5     Action,Adventure,Sci-Fi            7.3    665594  producer
# 6     Action,Adventure,Sci-Fi            7.3    665594     actor
# 7     Action,Adventure,Sci-Fi            7.3    665594     actor
# 8     Action,Adventure,Sci-Fi            7.3    665594     actor
# 9     Action,Adventure,Sci-Fi            7.3    665594     actor
# 10    Action,Adventure,Sci-Fi            7.3    665594  director
# 11    Action,Adventure,Sci-Fi            8.5    670926     actor
# 12    Action,Adventure,Sci-Fi            8.5    670926     actor
# 13    Action,Adventure,Sci-Fi            8.5    670926     actor
# 14    Action,Adventure,Sci-Fi            8.5    670926     actor
# 15    Action,Adventure,Sci-Fi            8.5    670926  director
# 16    Action,Adventure,Sci-Fi            8.5    670926  director
# 17   Action,Adventure,Fantasy            6.5    329135     actor
# 18   Action,Adventure,Fantasy            6.5    329135   actress
# 19   Action,Adventure,Fantasy            6.5    329135     actor
# 20   Action,Adventure,Fantasy            6.5    329135     actor
# 21   Action,Adventure,Fantasy            6.5    329135  director
# 22  Action,Adventure,Thriller            6.8    352504     actor
# 23  Action,Adventure,Thriller            6.8    352504     actor
# 24  Action,Adventure,Thriller            6.8    352504   actress
# 25  Action,Adventure,Thriller            6.8    352504     actor
# 26  Action,Adventure,Thriller            6.8    352504  director
# 27            Action,Thriller            8.4   1387769  producer
# 28            Action,Thriller            8.4   1387769     actor
# 29            Action,Thriller            8.4   1387769     actor
#
#                  name
# 0         Johnny Depp
# 1       Penélope Cruz
# 2         Ian McShane
# 3       Geoffrey Rush
# 4        Rob Marshall
# 5         Kevin Feige
# 6   Robert Downey Jr.
# 7         Chris Evans
# 8        Mark Ruffalo
# 9     Chris Hemsworth
# 10        Joss Whedon
# 11  Robert Downey Jr.
# 12    Chris Hemsworth
# 13       Mark Ruffalo
# 14        Chris Evans
# 15      Anthony Russo
# 16          Joe Russo
# 17        Ben Affleck
# 18          Gal Gadot
# 19        Jason Momoa
# 20        Ezra Miller
# 21        Zack Snyder
# 22       Daniel Craig
# 23    Christoph Waltz
# 24        Léa Seydoux
# 25      Ralph Fiennes
# 26         Sam Mendes
# 27        Emma Thomas
# 28     Christian Bale
# 29          Tom Hardy

# %%
master_movie['movie'].value_counts().head(20)
# Out:
# Robin Hood       62
# The Gambler      58
# One Day          46
# Anna             43
# Eden             39
# Youth            37
# Split            36
# The Journey      34
# Legend           34
# Joy              34
# Truth or Dare    33
# Mama             32
# Lights Out       30
# Unstoppable      29
# Abduction        29
# The House        28
# Creed            28
# Trance           26
# Upside Down      25
# Jackpot          24
# Name: movie, dtype: int64

# %%
len(master_movie['movie'].unique())
# Out:
# 1157

# %%
first_column = master_movie.pop('movie_id')

# %%
master_movie.insert(0, 'movie_id', first_column)

# %%
master_movie.head()
# Out:
#     movie_id release_date                                        movie  \
# 0  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 4  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross studio  \
# 0          410600000       241063875       1045663875     BV
# 1          410600000       241063875       1045663875     BV
# 2          410600000       241063875       1045663875     BV
# 3          410600000       241063875       1045663875     BV
# 4          410600000       241063875       1045663875     BV
#
#                      genres  averagerating  numvotes  category           name
# 0  Action,Adventure,Fantasy            6.6    447624     actor    Johnny Depp
# 1  Action,Adventure,Fantasy            6.6    447624   actress  Penélope Cruz
# 2  Action,Adventure,Fantasy            6.6    447624     actor    Ian McShane
# 3  Action,Adventure,Fantasy            6.6    447624     actor  Geoffrey Rush
# 4  Action,Adventure,Fantasy            6.6    447624  director   Rob Marshall

# %%
master_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9645 entries, 0 to 9644
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           9645 non-null   object
#  1   release_date       9645 non-null   datetime64[ns]
#  2   movie              9645 non-null   object
#  3   production_budget  9645 non-null   int64
#  4   domestic_gross     9645 non-null   int64
#  5   worldwide_gross    9645 non-null   int64
#  6   studio             9645 non-null   object
#  7   genres             9645 non-null   object
#  8   averagerating      9645 non-null   float64
#  9   numvotes           9645 non-null   int64
#  10  category           9645 non-null   object
#  11  name               9645 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 979.6+ KB

# %%
master_movie_unique = master_movie.copy()

# %%
master_movie_unique.drop(['category'], axis=1, inplace=True)

# %%
master_movie_unique.drop(['name'], axis=1, inplace=True)

# %%
master_movie_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9645 entries, 0 to 9644
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           9645 non-null   object
#  1   release_date       9645 non-null   datetime64[ns]
#  2   movie              9645 non-null   object
#  3   production_budget  9645 non-null   int64
#  4   domestic_gross     9645 non-null   int64
#  5   worldwide_gross    9645 non-null   int64
#  6   studio             9645 non-null   object
#  7   genres             9645 non-null   object
#  8   averagerating      9645 non-null   float64
#  9   numvotes           9645 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 828.9+ KB

# %%
master_movie_unique.drop_duplicates(subset='movie_id', ignore_index=True, inplace=True)

# %%
master_movie_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           1393 non-null   object
#  1   release_date       1393 non-null   datetime64[ns]
#  2   movie              1393 non-null   object
#  3   production_budget  1393 non-null   int64
#  4   domestic_gross     1393 non-null   int64
#  5   worldwide_gross    1393 non-null   int64
#  6   studio             1393 non-null   object
#  7   genres             1393 non-null   object
#  8   averagerating      1393 non-null   float64
#  9   numvotes           1393 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 109.0+ KB

# %%
master_movie_unique.head()
# Out:
#     movie_id release_date                                        movie  \
# 0  tt1298650   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 1  tt2395427   2015-05-01                      Avengers: Age of Ultron
# 2  tt4154756   2018-04-27                       Avengers: Infinity War
# 3  tt0974015   2017-11-17                               Justice League
# 4  tt2379713   2015-11-06                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross studio  \
# 0          410600000       241063875       1045663875     BV
# 1          330600000       459005868       1403013963     BV
# 2          300000000       678815482       2048134200     BV
# 3          300000000       229024295        655945209     WB
# 4          300000000       200074175        879620923   Sony
#
#                       genres  averagerating  numvotes
# 0   Action,Adventure,Fantasy            6.6    447624
# 1    Action,Adventure,Sci-Fi            7.3    665594
# 2    Action,Adventure,Sci-Fi            8.5    670926
# 3   Action,Adventure,Fantasy            6.5    329135
# 4  Action,Adventure,Thriller            6.8    352504

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
master_movie_unique.describe()
# Out:
#        production_budget  domestic_gross  worldwide_gross  averagerating  \
# count         1393.00000      1393.00000       1393.00000     1393.00000
# mean      46536984.59296  60716765.12132  151889415.58794        6.43345
# std       55319591.25846  84783512.38835  233883878.84803        1.03109
# min          50000.00000         0.00000          0.00000        1.60000
# 25%       10000000.00000   7634767.00000   18273009.00000        5.90000
# 50%       25000000.00000  33680992.00000   65759911.00000        6.50000
# 75%       58000000.00000  75605492.00000  170936470.00000        7.10000
# max      410600000.00000 700059566.00000 2048134200.00000        9.20000
#
#            numvotes
# count    1393.00000
# mean   114092.50179
# std    164889.33271
# min         5.00000
# 25%     13121.00000
# 50%     59229.00000
# 75%    137734.00000
# max   1841066.00000

# %%
import matplotlib.pyplot as plt

x1 = master_movie_unique['production_budget']
x2 = master_movie_unique['domestic_gross']
x3 = master_movie_unique['worldwide_gross']
x4 = master_movie_unique['averagerating']
x5 = master_movie_unique['numvotes']
plt.boxplot([x1,x2,x3,x4,x5]);

# %%
import numpy as np

def outlier_treatment(x, lower, upper):
    if (lower >= x) or (x >= upper):
        return 'Yes'
    else:
        return 'No'

columns_to_check = ['production_budget', 'domestic_gross', 'worldwide_gross', 
                    'averagerating', 'numvotes']

for col in columns_to_check: 
    Q1,Q3 = np.percentile(master_movie_unique[col],[25,75])
    IQR = Q3 - Q1
    
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)
    
    master_movie_unique['outlier'] = master_movie_unique[col].apply(lambda x: outlier_treatment(x, lower_bound,upper_bound))
    print(f"The lower and upper bound of the range for '{col}' respectively is: {lower_bound} and {upper_bound}")
# Out:
# The lower and upper bound of the range for 'production_budget' respectively is: -62000000.0 and 130000000.0
# The lower and upper bound of the range for 'domestic_gross' respectively is: -94321320.5 and 177561579.5
# The lower and upper bound of the range for 'worldwide_gross' respectively is: -210722182.5 and 399931661.5
# The lower and upper bound of the range for 'averagerating' respectively is: 4.100000000000001 and 8.899999999999999
# The lower and upper bound of the range for 'numvotes' respectively is: -173798.5 and 324653.5

# %%
master_movie_unique['production_budget'].value_counts()
# Out:
# 10000000    60
# 20000000    59
# 40000000    55
# 25000000    50
# 30000000    47
#             ..
# 97000000     1
# 82000000     1
# 175000       1
# 52500000     1
# 9700000      1
# Name: production_budget, Length: 215, dtype: int64

# %%
master_movie_unique['domestic_gross'].value_counts()
# Out:
# 0            19
# 13843771      6
# 138141585     6
# 71628180      5
# 2703296       5
#              ..
# 15951040      1
# 159581587     1
# 42073277      1
# 14915773      1
# 237282182     1
# Name: domestic_gross, Length: 1151, dtype: int64

# %%
master_movie_unique['worldwide_gross'].value_counts()
# Out:
# 0            8
# 59168692     6
# 1200000      6
# 278964806    6
# 38718031     5
#             ..
# 53068955     1
# 25529498     1
# 17061        1
# 101985431    1
# 74326015     1
# Name: worldwide_gross, Length: 1156, dtype: int64

# %%
master_movie_unique['averagerating'].value_counts()
# Out:
# 6.60000    76
# 6.30000    73
# 6.80000    64
# 7.00000    63
# 6.40000    63
#            ..
# 2.40000     1
# 3.70000     1
# 1.70000     1
# 2.10000     1
# 3.00000     1
# Name: averagerating, Length: 65, dtype: int64

# %%
master_movie_unique['numvotes'].value_counts()
# Out:
# 6         13
# 8         11
# 12         9
# 14         9
# 10         8
#           ..
# 111907     1
# 3793       1
# 40229      1
# 104465     1
# 34816      1
# Name: numvotes, Length: 1296, dtype: int64
